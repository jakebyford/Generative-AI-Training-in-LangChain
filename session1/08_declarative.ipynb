# %% [markdown]
# # Declarative Composition
#
# LCEL is a <em>declarative language</em> for composing LangChain components. LangChain compiles LCEL compositions to an <em>optimized execution plan</em>, with automatic parallelization, streaming, tracing, and async support.
#
# - Uses a more concise, pipeline-like approach
# - Leverages the | (pipe) operator to chain components
# - Provides a cleaner, more readable syntax
# - Easier to compose and chain different components
#
# Let’s see the same example using LCEL:

# %%
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

# the building blocks

template = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a helpful assistant."),
        ("human", "{question}"),
    ]
)

model = ChatOpenAI()

# combine them with the | operator

chatbot = template | model

# use it

response = chatbot.invoke({"question": "Which model providers offer LLMs?"})
print(response.content)

# streaming

for part in chatbot.stream({"question": "Which model providers offer LLMs?"}):
    print(part)
# Out:
# Many law schools around the world offer LLM (Master of Laws) programs. Some well-known law schools that offer LLM programs include Harvard Law School, Yale Law School, Stanford Law School, Oxford University, and Cambridge University. Additionally, many other universities and law schools globally offer LLM programs with various specializations. It is best to check the individual websites of specific law schools for more information on their LLM offerings.
# content='' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content='There' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' are' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' a' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' variety' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' of' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' model' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' providers' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' that' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' offer' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' Limited' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' Liability' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' Models' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' (' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content='LL' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content='Ms' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=')' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' for' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' businesses' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content='.' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' Some' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' popular' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' model' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' providers' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' that' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' offer' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' L' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content='LM' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content='s' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' include' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' Legal' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content='Zoom' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=',' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' Rocket' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' Lawyer' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=',' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' N' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content='olo' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=',' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' and' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' Up' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content='C' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content='ounsel' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content='.' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' Additionally' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=',' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' many' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' law' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' firms' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' and' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' legal' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' services' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' companies' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' may' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' also' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' offer' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' customized' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' L' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content='LM' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' templates' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' for' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' businesses' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content='.' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' It' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content="'s" additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' important' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' to' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' carefully' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' review' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' the' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' terms' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' and' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' conditions' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' of' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' any' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' model' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' provider' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' before' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' purchasing' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' and' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' using' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' their' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' L' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content='LM' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' to' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' ensure' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' it' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' meets' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' your' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' specific' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' business' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content=' needs' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content='.' additional_kwargs={} response_metadata={} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'
# content='' additional_kwargs={} response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-3.5-turbo-0125'} id='run-3ebdc08e-d78b-4323-8da3-e42ac524a4e9'

# %%
chatbot = template | model

await chatbot.ainvoke({
    "question": "Which model providers offer LLMs?"
})
# Out:
# AIMessage(content="There are many institutions that offer LLM (Master of Laws) programs. Some of the top institutions known for their LLM programs include:\n\n1. Harvard Law School\n2. Yale Law School\n3. Stanford Law School\n4. University of Cambridge\n5. University of Oxford\n6. New York University School of Law\n7. University of California, Berkeley School of Law\n8. London School of Economics and Political Science (LSE)\n9. Columbia Law School\n10. University of Chicago Law School\n\nThese are just a few examples, and there are many other reputable institutions worldwide that offer LLM programs. It's important to research and find a program that aligns with your interests and career goals.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 146, 'prompt_tokens': 25, 'total_tokens': 171, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-b9fcc75a-7e81-45a8-83b5-6a268a621b23-0', usage_metadata={'input_tokens': 25, 'output_tokens': 146, 'total_tokens': 171, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# #

# %% [markdown]
# Crucially, the last line is the same between the two examples—that is, you use the function and the LCEL sequence in the same way, with ```invoke/stream/batch```. And in this version, you don’t need to do anything else to use streaming:

# %%
chatbot = template | model

for part in chatbot.stream({
    "question": "Which model providers offer LLMs?"
}):
    print(part)
# Out:
# content='' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='There' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' are' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' several' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' law' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' schools' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' and' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' universities' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' around' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' the' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' world' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' that' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' offer' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' Master' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' of' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' Laws' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' (' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='LL' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='M' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=')' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' programs' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='.' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' Some' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' well' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='-known' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' institutions' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' that' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' offer' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' L' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='LM' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' degrees' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' include' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=':\n\n' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='1' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='.' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' Harvard' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' Law' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' School' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='\n' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='2' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='.' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' Yale' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' Law' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' School' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='\n' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='3' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='.' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' Stanford' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' Law' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' School' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='\n' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='4' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='.' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' University' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' of' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' Cambridge' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='\n' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='5' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='.' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' University' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' of' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' Oxford' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='\n' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='6' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='.' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' New' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' York' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' University' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' School' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' of' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' Law' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='\n' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='7' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='.' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' London' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' School' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' of' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' Economics' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' and' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' Political' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' Science' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='\n' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='8' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='.' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' University' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' of' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' California' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=',' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' Berkeley' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='\n' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='9' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='.' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' University' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' of' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' Melbourne' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='\n' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='10' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='.' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' Georgetown' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' University' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' Law' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' Center' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='\n\n' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='These' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' are' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' just' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' a' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' few' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' of' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' the' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' many' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' institutions' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' that' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' offer' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' L' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='LM' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' programs' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='.' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' It' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content="'s" additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' important' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' to' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' research' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' and' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' find' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' the' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' program' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' that' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' best' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' suits' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' your' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' academic' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' and' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' career' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content=' goals' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='.' additional_kwargs={} response_metadata={} id='run-67ff164c-cb64-4654-803e-22a7594be968'
# content='' additional_kwargs={} response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-3.5-turbo-0125'} id='run-67ff164c-cb64-4654-803e-22a7594be968'

# %% [markdown]
# #

# %% [markdown]
# And, for Python only, it’s the same for using asynchronous methods:

# %%
chatbot = template | model

await chatbot.ainvoke({
    "question": "Which model providers offer LLMs?"
})
# Out:
# AIMessage(content="Several prestigious universities around the world offer LLM (Master of Laws) programs. Some well-known institutions known for their LLM programs include:\n\n1. Harvard Law School (USA)\n2. Yale Law School (USA)\n3. Stanford Law School (USA)\n4. University of Oxford (UK)\n5. University of Cambridge (UK)\n6. London School of Economics and Political Science (LSE) (UK)\n7. University of Melbourne (Australia)\n8. National University of Singapore (NUS) (Singapore)\n9. University of Toronto (Canada)\n10. Peking University (China)\n\nThese are just a few examples, and many other universities worldwide also offer LLM programs. It's essential to research each program's specifics, faculty, and specializations to find the best fit for your academic and career goals.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 167, 'prompt_tokens': 25, 'total_tokens': 192, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-2b26109b-fae7-4fcb-8806-fc32c0cf227e-0', usage_metadata={'input_tokens': 25, 'output_tokens': 167, 'total_tokens': 192, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
