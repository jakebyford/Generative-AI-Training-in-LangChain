# %%
from langchain_core.runnables import chain
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate


model = ChatOpenAI(model="gpt-3.5-turbo")


template = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a helpful assistant."),
        ("human", "{question}"),
    ]
)


@chain
def chatbot(values):
    prompt = template.invoke(values)
    for token in model.stream(prompt):
        yield token


for part in chatbot.stream({"question": "Which model providers offer LLMs?"}):
    print(part)
    # print(part.content)
# Out:
# content='' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content='Several' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' model' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' providers' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' offer' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' Limited' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' Liability' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' Models' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' (' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content='LL' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content='Ms' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=')' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' for' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' businesses' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content='.' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' Some' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' common' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' examples' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' include' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' Legal' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content='Zoom' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=',' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' Rocket' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' Lawyer' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=',' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' and' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' Inc' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content='file' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content='.' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' These' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' providers' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' can' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' help' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' you' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' set' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' up' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' and' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' maintain' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' your' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' limited' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' liability' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' company' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' (' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content='LL' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content='C' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=')' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' by' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' filling' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' out' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' necessary' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' paperwork' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=',' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' providing' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' legal' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' guidance' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=',' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' and' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' registering' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' your' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' business' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' with' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' the' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' appropriate' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' authorities' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content='.' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' Be' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' sure' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' to' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' research' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' each' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' provider' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' to' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' find' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' the' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' one' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' that' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' best' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' fits' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' your' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' needs' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' and' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content=' budget' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content='.' additional_kwargs={} response_metadata={} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
# content='' additional_kwargs={} response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-3.5-turbo-0125'} id='run-2f351c57-c9fc-4a76-8fb6-388612857025'
