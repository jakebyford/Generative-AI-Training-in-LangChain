# %%
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

# the building blocks

template = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a helpful assistant."),
        ("human", "{question}"),
    ]
)

model = ChatOpenAI()

# combine them with the | operator

chatbot = template | model

# use it

response = chatbot.invoke({"question": "Which model providers offer LLMs?"})
print(response.content)

# streaming

for part in chatbot.stream({"question": "Which model providers offer LLMs?"}):
    print(part)
# Out:
# Many universities and law schools around the world offer Master of Laws (LLM) programs. Some of the well-known model providers of LLM programs include:
#
# 1. Harvard Law School
# 2. Yale Law School
# 3. Stanford Law School
# 4. University of Cambridge
# 5. University of Oxford
# 6. University of Melbourne
# 7. New York University School of Law
# 8. London School of Economics and Political Science (LSE)
# 9. University of California, Berkeley (UC Berkeley)
# 10. University of Chicago Law School
#
# These are just a few examples, and there are many other reputable institutions that offer LLM programs. It's important to research and choose a program that aligns with your academic and career goals.
# content='' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='Several' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' model' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' providers' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' offer' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' Legal' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' Entity' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' Ident' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='ifiers' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' (' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='LE' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='Is' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=')' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' which' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' are' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' ' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='20' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='-character' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' alphanumeric' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' codes' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' used' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' to' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' uniquely' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' identify' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' legal' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' entities' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' that' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' participate' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' in' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' financial' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' transactions' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='.' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' Some' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' popular' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' model' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' providers' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' offering' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' LE' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='Is' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' include' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=':' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' \n\n' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='1' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='.' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' Bloomberg' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' \n' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='2' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='.' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' Ref' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='init' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='iv' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' (' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='formerly' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' known' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' as' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' Thomson' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' Reuters' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=')\n' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='3' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='.' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' Dun' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' &' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' Brad' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='street' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='\n' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='4' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='.' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' Rapid' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='LE' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='I' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='\n' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='5' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='.' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' Legal' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='entity' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' Identifier' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' (' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='LE' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='I' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=')' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' Registr' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='ations' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='\n\n' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='You' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' can' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' explore' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' these' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' providers' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' to' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' obtain' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' an' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' LE' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='I' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' for' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' your' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' legal' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content=' entity' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='.' additional_kwargs={} response_metadata={} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'
# content='' additional_kwargs={} response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-3.5-turbo-0125'} id='run-e0c9cf51-3cae-4da0-b84b-b61e74c17d08'

# %%
chatbot = template | model

await chatbot.ainvoke({
    "question": "Which model providers offer LLMs?"
})
# Out:
# AIMessage(content='In the meanwhile, do you have any specific model provider or organization in mind?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 25, 'total_tokens': 42, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-dc4e5eb9-7283-4f44-a302-a4aa6cb2bb1e-0', usage_metadata={'input_tokens': 25, 'output_tokens': 17, 'total_tokens': 42, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
