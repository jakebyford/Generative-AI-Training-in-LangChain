# %% [markdown]
# # Using LangGraph to Add Memory to Your Chatbot
# ## Memory and retrieval used to generate context-aware answers from an LLM
# ![image.png](attachment:cec74407-19d5-4a70-a66f-10d13fec4a40.png)

# %% [markdown]
# ## Building a Chatbot Memory System
# ![image.png](attachment:ba071e3b-8806-41d9-bb87-979d155614f6.png)

# %% [markdown]
# ## Introducing LangGraph
#
# ### From single-actor to multiactor applications
#
# ![image.png](attachment:47920042-ead7-463d-b2ef-0abfa7eef7e1.png)

# %% [markdown]
# ### From multiactor to multistep
#
# ![image.png](attachment:c4036cac-5de9-4c50-b016-ed9920122e07.png)

# %% [markdown]
# ### From multistep to stateful applications
#
# ![image.png](attachment:f0476015-2506-4d0e-920b-59496bb7c907.png)

# %% [markdown]
# # Creating a StateGraph

# %% [markdown]
# # Adding Memory to StateGraph
